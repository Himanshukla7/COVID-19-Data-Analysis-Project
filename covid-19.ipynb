# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv(r"E:\jobaaj\python\covid19_Confirmed_dataset.csv")

# %%
data.head()
# Out:
#   Province/State Country/Region      Lat     Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN    Afghanistan  33.0000  65.0000        0        0        0
# 1            NaN        Albania  41.1533  20.1683        0        0        0
# 2            NaN        Algeria  28.0339   1.6596        0        0        0
# 3            NaN        Andorra  42.5063   1.5218        0        0        0
# 4            NaN         Angola -11.2027  17.8739        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...     1092     1176     1279     1351
# 1        0        0        0  ...      609      634      663      678
# 2        0        0        0  ...     2811     2910     3007     3127
# 3        0        0        0  ...      717      723      723      731
# 4        0        0        0  ...       24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
data.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '4/21/20', '4/22/20', '4/23/20', '4/24/20', '4/25/20', '4/26/20',
#        '4/27/20', '4/28/20', '4/29/20', '4/30/20'],
#       dtype='object', length=104)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 266 entries, 0 to 265
# Columns: 104 entries, Province/State to 4/30/20
# dtypes: float64(2), int64(100), object(2)
# memory usage: 216.3+ KB

# %%
data.describe()
# Out:
#               Lat        Long     1/22/20     1/23/20     1/24/20     1/25/20  \
# count  266.000000  266.000000  266.000000  266.000000  266.000000  266.000000
# mean    21.259359   22.432499    2.086466    2.458647    3.537594    5.390977
# std     24.747943   70.478908   27.279200   27.377862   34.083035   47.434934
# min    -51.796300 -135.000000    0.000000    0.000000    0.000000    0.000000
# 25%      6.907750  -18.093125    0.000000    0.000000    0.000000    0.000000
# 50%     23.488100   20.921188    0.000000    0.000000    0.000000    0.000000
# 75%     41.143200   77.191525    0.000000    0.000000    0.000000    0.000000
# max     71.706900  178.065000  444.000000  444.000000  549.000000  761.000000
#
#            1/26/20      1/27/20      1/28/20      1/29/20  ...        4/21/20  \
# count   266.000000   266.000000   266.000000   266.000000  ...     266.000000
# mean      7.962406    11.003759    20.969925    23.180451  ...    9582.033835
# ...

# %%
data_india = data[data['Country/Region'] == "India"].reset_index(drop=True)

# %%
data_india
# Out:
#   Province/State Country/Region   Lat  Long  1/22/20  1/23/20  1/24/20  \
# 0            NaN          India  21.0  78.0        0        0        0
#
#    1/25/20  1/26/20  1/27/20  ...  4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0  ...    20080    21370    23077    24530
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# 0    26283    27890    29451    31324    33062    34863
#
# [1 rows x 104 columns]

# %%
# we are dropping 'Province/State' and 'Country/Region'

data_india.drop(['Province/State', 'Country/Region', 'Lat', 'Long'], axis=1, inplace=True)

# Making it column wise data

data_india = data_india.T

# %%
data_india
# Out:
#              0
# 1/22/20      0
# 1/23/20      0
# 1/24/20      0
# 1/25/20      0
# 1/26/20      0
# ...        ...
# 4/26/20  27890
# 4/27/20  29451
# 4/28/20  31324
# 4/29/20  33062
# 4/30/20  34863
#
# [100 rows x 1 columns]

# %%
def country_wise_data(data, country_name):
    data_country_name = data[data['Country/Region'] == country_name].reset_index(drop=True)
    data_country_name.drop(['Province/State', 'Country/Region', 'Lat', 'Long'], axis=1, inplace=True)
    data_country_name = data_country_name.T
    return data_country_name

# %%
data_india = country_wise_data(data ,"India")

# %%
data_india
# Out:
#              0
# 1/22/20      0
# 1/23/20      0
# 1/24/20      0
# 1/25/20      0
# 1/26/20      0
# ...        ...
# 4/26/20  27890
# 4/27/20  29451
# 4/28/20  31324
# 4/29/20  33062
# 4/30/20  34863
#
# [100 rows x 1 columns]

# %%
data_afghan = country_wise_data(data ,"Afghanistan")
data_afghan
# Out:
#             0
# 1/22/20     0
# 1/23/20     0
# 1/24/20     0
# 1/25/20     0
# 1/26/20     0
# ...       ...
# 4/26/20  1531
# 4/27/20  1703
# 4/28/20  1828
# 4/29/20  1939
# 4/30/20  2171
#
# [100 rows x 1 columns]

# %%
data_india.index
# Out:
# Index(['1/22/20', '1/23/20', '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        '1/28/20', '1/29/20', '1/30/20', '1/31/20', '2/1/20', '2/2/20',
#        '2/3/20', '2/4/20', '2/5/20', '2/6/20', '2/7/20', '2/8/20', '2/9/20',
#        '2/10/20', '2/11/20', '2/12/20', '2/13/20', '2/14/20', '2/15/20',
#        '2/16/20', '2/17/20', '2/18/20', '2/19/20', '2/20/20', '2/21/20',
#        '2/22/20', '2/23/20', '2/24/20', '2/25/20', '2/26/20', '2/27/20',
#        '2/28/20', '2/29/20', '3/1/20', '3/2/20', '3/3/20', '3/4/20', '3/5/20',
#        '3/6/20', '3/7/20', '3/8/20', '3/9/20', '3/10/20', '3/11/20', '3/12/20',
#        '3/13/20', '3/14/20', '3/15/20', '3/16/20', '3/17/20', '3/18/20',
#        '3/19/20', '3/20/20', '3/21/20', '3/22/20', '3/23/20', '3/24/20',
#        '3/25/20', '3/26/20', '3/27/20', '3/28/20', '3/29/20', '3/30/20',
#        '3/31/20', '4/1/20', '4/2/20', '4/3/20', '4/4/20', '4/5/20', '4/6/20',
#        '4/7/20', '4/8/20', '4/9/20', '4/10/20', '4/11/20', '4/12/20',
# ...

# %%
data_india.index = pd.DatetimeIndex(data_india.index)

# %%
data_india.index
# Out:
# DatetimeIndex(['2020-01-22', '2020-01-23', '2020-01-24', '2020-01-25',
#                '2020-01-26', '2020-01-27', '2020-01-28', '2020-01-29',
#                '2020-01-30', '2020-01-31', '2020-02-01', '2020-02-02',
#                '2020-02-03', '2020-02-04', '2020-02-05', '2020-02-06',
#                '2020-02-07', '2020-02-08', '2020-02-09', '2020-02-10',
#                '2020-02-11', '2020-02-12', '2020-02-13', '2020-02-14',
#                '2020-02-15', '2020-02-16', '2020-02-17', '2020-02-18',
#                '2020-02-19', '2020-02-20', '2020-02-21', '2020-02-22',
#                '2020-02-23', '2020-02-24', '2020-02-25', '2020-02-26',
#                '2020-02-27', '2020-02-28', '2020-02-29', '2020-03-01',
#                '2020-03-02', '2020-03-03', '2020-03-04', '2020-03-05',
#                '2020-03-06', '2020-03-07', '2020-03-08', '2020-03-09',
#                '2020-03-10', '2020-03-11', '2020-03-12', '2020-03-13',
# ...

# %%
data_india
# Out:
#                 0
# 2020-01-22      0
# 2020-01-23      0
# 2020-01-24      0
# 2020-01-25      0
# 2020-01-26      0
# ...           ...
# 2020-04-26  27890
# 2020-04-27  29451
# 2020-04-28  31324
# 2020-04-29  33062
# 2020-04-30  34863
#
# [100 rows x 1 columns]

# %%
data_india.plot()
# Out:
# <Axes: >

# %%
number_of_cases = data_india.values
dates = data_india.index.values

# %%
# %matplotlib inline

plt.figure(figsize = (8,6))
plt.plot(dates, number_of_cases, label="India")
plt.legend()
plt.grid()
plt.show()

# %%
# %matplotlib inline

def covid_visulization(data, countries = []):
    
    plt.figure(figsize=(8,6))
    
    for country in countries:
        
        data_country = country_wise_data(data, country_name=country)
        
        data_country.index = pd.DatetimeIndex(data_country.index)
        
        number_of_cases = data_country.values
        
        dates = data_country.index.values
        
        plt.plot(dates, number_of_cases, label=country)
        
    plt.legend()
    
    plt.grid()
    
    plt.show()

# %%
covid_visulization(data, countries = ["India", "Afghanistan", "Italy", "Germany"])

# %%
### Q1: Which country had highest number of cases till the month of April, 2020

### Answer: US

# %%
total_cases = data.iloc[:, 4:].sum(axis=1)

countries = data["Country/Region"]

country_wise_total_cases = pd.concat([countries, total_cases], axis = 1).rename(columns={"Country/Region": "Country", 0:"total_cases"})

# %%
country_wise_total_cases
# Out:
#                    Country  total_cases
# 0              Afghanistan        28462
# 1                  Albania        17864
# 2                  Algeria        74325
# 3                  Andorra        21893
# 4                   Angola          649
# ..                     ...          ...
# 261         Western Sahara          142
# 262  Sao Tome and Principe          118
# 263                  Yemen           31
# 264                Comoros            1
# 265             Tajikistan           15
#
# [266 rows x 2 columns]

# %%
max_count = country_wise_total_cases['total_cases'].max()

country_wise_total_cases[country_wise_total_cases['total_cases'] == max_count]
# Out:
#     Country  total_cases
# 225      US     20606211

# %%
### Q2:  Which country has loweset number of confirmed cases till april 2020

### Ans: Canada

# %%
min_count = country_wise_total_cases['total_cases'].min()

country_wise_total_cases[country_wise_total_cases['total_cases'] == min_count]
# Out:
#     Country  total_cases
# 231  Canada            0
# 238  Canada            0

# %%
### Q3: Given a country name can you find total number of confirmed cases till April, 2020?

# %%
country_name = "Sri Lanka"

country_wise_total_cases[country_wise_total_cases["Country"]==country_name]
# Out:
#        Country  total_cases
# 202  Sri Lanka        10572

# %%
### Q4: Show the covid-19 confirmed cases by dates for India and its neighbours

### neighbours: Pakistan, Afganistan, Nepal, Bhutan, Bangladesh, Mayanmar, Sri Lanka

# %%
def return_country_wise_total_cases(country_wise_total_cases , countries =[]):
    for country in countries:
        country_name = country
        print(country_wise_total_cases[country_wise_total_cases["Country"]==country_name])

# %%
return_country_wise_total_cases(country_wise_total_cases ,countries = ["India", "Pakistan", "Afganistan", "Nepal", "Bhutan", "Bangladesh", "Mayanmar", "Sri Lanka"])
# Out:
#     Country  total_cases
# 131   India       457945
#       Country  total_cases
# 177  Pakistan       245996
# Empty DataFrame
# Columns: [Country, total_cases]
# Index: []
#     Country  total_cases
# 165   Nepal          884
#    Country  total_cases
# 25  Bhutan          213
#        Country  total_cases
# 20  Bangladesh        70829
# Empty DataFrame
# Columns: [Country, total_cases]
# Index: []
#        Country  total_cases
# 202  Sri Lanka        10572

# %%
country_list = ["India", "Pakistan", "Afganistan", "Nepal", "Bhutan", "Bangladesh", "Mayanmar", "Sri Lanka"]

# %%
# %matplotlib inline

covid_visulization(data, country_list)

# %%
data = country_wise_total_cases[country_wise_total_cases['Country'].isin(country_list)]

# %%
country_names = data.Country.values

total_cases = data.total_cases.values

# %%
# %matplotlib inline

plt.bar(x=range(len(total_cases)), height=total_cases, tick_label=country_names)
plt.grid()
plt.show()
